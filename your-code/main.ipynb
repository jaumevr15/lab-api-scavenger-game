# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
url = 'https://api.github.com'
username = 'jaumevr15'
token = 'a9b2897b09dbd4e8645a2887cdf94a7c6865859e'
login = requests.get('https://api.github.com/repos/ta-data-bcn/lab-api-scavenger-game/forks', auth=(username,token))
bcn_forks = (json.dumps(login.json(), indent=4))
bcn_df = pd.DataFrame(login.json())
bcn_df.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/GuillemGodayol/la...     False
# 1  https://api.github.com/repos/JordiJordana/lab-...     False
# 2  https://api.github.com/repos/pszewach/lab-api-...     False
# 3  https://api.github.com/repos/AlexNavarroLlecha...     False
# 4  https://api.github.com/repos/VladimirAutier/la...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/GuillemGodayol/la...
# 1  https://api.github.com/repos/JordiJordana/lab-...
# 2  https://api.github.com/repos/pszewach/lab-api-...
# 3  https://api.github.com/repos/AlexNavarroLlecha...
# 4  https://api.github.com/repos/VladimirAutier/la...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/GuillemGodayol/la...
# 1  https://api.github.com/repos/JordiJordana/lab-...
# 2  https://api.github.com/repos/pszewach/lab-api-...
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
language = []
[language.append(x['language']) for x in login.json() if x['language'] not in language]
language
# Out:
# [None, 'Jupyter Notebook', 'Python']

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
com_login = requests.get('https://api.github.com/repos/ta-data-bcn/lab-api-scavenger-game/commits', auth=(username,token))
bcn_com = (json.dumps(com_login.json(), indent=4))
bcn_com_df = pd.DataFrame(com_login.json())
bcn_com_df
# Out:
#                                               author  \
# 0  {'login': 'evapanizo', 'id': 9594137, 'node_id...
# 1  {'login': 'NachoMartinezJ', 'id': 27884808, 'n...
# 2  {'login': 'NachoMartinezJ', 'id': 27884808, 'n...
# 3  {'login': 'evapanizo', 'id': 9594137, 'node_id...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ta-data-bcn/lab-a...
# 1  https://api.github.com/repos/ta-data-bcn/lab-a...
# 2  https://api.github.com/repos/ta-data-bcn/lab-a...
# 3  https://api.github.com/repos/ta-data-bcn/lab-a...
#
#                                               commit  \
# 0  {'author': {'name': 'Eva Panizo', 'email': 'pa...
# 1  {'author': {'name': 'Nacho', 'email': 'nacho.0...
# 2  {'author': {'name': 'Nacho', 'email': 'nacho.0...
# 3  {'author': {'name': 'Eva Panizo', 'email': 'pa...
#
#                                            committer  \
# 0  {'login': 'evapanizo', 'id': 9594137, 'node_id...
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
commits = []
[commits.append(x['commit']) for x in com_login.json() if x['commit'] not in commits]
len(commits)
# Out:
# 4

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
username = 'jaumevr15'
token = 'a9b2897b09dbd4e8645a2887cdf94a7c6865859e'
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger',auth=(username,token))
search = response.json()
files = search['items']
# Out:
# 24

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
files = sorted(files, key = lambda file: file['name'])
files
# Out:
# [{'name': '.0001.scavengerhunt',
#   'path': '98750/.0001.scavengerhunt',
#   'sha': '2add7632f1323136324efbf38ec66db1838b6173',
#   'url': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
headers = {'Accept': 'application/vnd.github.v3.raw'}
final=[]
params = {'client_id': 'jaumevr15', 'client_secret':'a9b2897b09dbd4e8645a2887cdf94a7c6865859e'}
for file in files:
    url = f"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{file['path']}"
    response = requests.get(url, params=params, headers = headers)
    final.append(response.text)

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
new_final = [word.strip('\n') for word in final]
joke = " ".join(new_final)

# %% [markdown]
# #### 5. Print out the joke.

# %%
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
